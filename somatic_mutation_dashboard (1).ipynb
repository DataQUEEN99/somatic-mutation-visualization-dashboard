# %% [markdown]
# # Somatic Mutation Visualization Dashboard (Interactive)
#
# This Colab notebook loads example mutation data, cleans it, and produces interactive plots using Plotly.
# No upload needed — a small demo MAF dataset is included programmatically.
#
# ---
#
# ## 1. Install & Import Libraries

# %%
# !pip install pandas plotly
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (5.24.1)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly) (9.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from plotly) (25.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %% [markdown]
# ## 2. Load Example Somatic Mutation Dataset
# The dataset is auto-created here (small demo MAF-like table).
# Replace this later with TCGA/ICGC real data if needed.

# %%
data = {
    "Hugo_Symbol": ["TP53","PIK3CA","KRAS","TP53","APC","PIK3CA","KRAS","BRAF","TP53","PTEN"],
    "Variant_Classification": ["Missense","Missense","Nonsense","Frameshift","Missense","Inframe","Missense","Missense","Splice","Nonsense"],
    "Variant_Type":["SNP","SNP","SNP","DEL","SNP","INS","SNP","SNP","SNP","SNP"],
    "Chromosome":["17","3","12","17","5","3","12","7","17","10"],
    "Start_Position":[7574000, 178952000, 25398200, 7573920, 112175000, 178952500, 25398300, 140753336, 7574100, 89720000],
}
df = pd.DataFrame(data)
df
# Out:
#   Hugo_Symbol Variant_Classification Variant_Type Chromosome  Start_Position
# 0        TP53               Missense          SNP         17         7574000
# 1      PIK3CA               Missense          SNP          3       178952000
# 2        KRAS               Nonsense          SNP         12        25398200
# 3        TP53             Frameshift          DEL         17         7573920
# 4         APC               Missense          SNP          5       112175000
# 5      PIK3CA                Inframe          INS          3       178952500
# 6        KRAS               Missense          SNP         12        25398300
# 7        BRAF               Missense          SNP          7       140753336
# 8        TP53                 Splice          SNP         17         7574100
# 9        PTEN               Nonsense          SNP         10        89720000

# %% [markdown]
# ## 3. Mutation Count per Gene (Interactive Bar Plot)

# %%
gene_counts = df["Hugo_Symbol"].value_counts().reset_index()
gene_counts.columns = ["Gene","Count"]
fig = px.bar(gene_counts, x="Gene", y="Count", title="Mutation Count per Gene")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0009a54f-4c63-4555-a445-4ac5a5e2b802" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0009a54f-4c63-4555-a445-4ac5a5e2b802")) {                    Plotly.newPlot(                        "0009a54f-4c63-4555-a445-4ac5a5e2b802",                        [{"alignmentgroup":"True","hovertemplate":"Gene=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["TP53","PIK3CA","KRAS","APC","BRAF","PTEN"],"xaxis":"x","y":[3,2,2,1,1,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"tick ...

# %% [markdown]
# ## 4. Mutation Types Distribution (Pie Chart)

# %%
fig = px.pie(df, names="Variant_Classification", title="Mutation Type Distribution")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ec778b98-9009-4c49-99d0-7f9061391790" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ec778b98-9009-4c49-99d0-7f9061391790")) {                    Plotly.newPlot(                        "ec778b98-9009-4c49-99d0-7f9061391790",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Variant_Classification=%{label}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Missense","Missense","Nonsense","Frameshift","Missense","Inframe","Missense","Missense","Splice","Nonsense"],"legendgroup":"","name":"","showlegend":true,"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar ...

# %% [markdown]
# ## 5. Chromosome Mutation Density (Scatter)

# %%
fig = px.scatter(df, x="Start_Position", y="Chromosome",
                 color="Hugo_Symbol",
                 title="Chromosomal Mutation Distribution",
                 hover_data=df.columns)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4c22c74b-1e58-425d-a6b3-508a789fa38c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4c22c74b-1e58-425d-a6b3-508a789fa38c")) {                    Plotly.newPlot(                        "4c22c74b-1e58-425d-a6b3-508a789fa38c",                        [{"customdata":[["TP53","Missense","SNP"],["TP53","Frameshift","DEL"],["TP53","Splice","SNP"]],"hovertemplate":"Hugo_Symbol=%{customdata[0]}\u003cbr\u003eStart_Position=%{x}\u003cbr\u003eChromosome=%{y}\u003cbr\u003eVariant_Classification=%{customdata[1]}\u003cbr\u003eVariant_Type=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"TP53","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"TP53","orientation":"h","showlegend":true,"x":[7574000,7573920,7574100],"xaxis":"x","y":["17","17","17"],"yaxis":"y","type":"scatter"},{"customdata":[["PIK3CA","Missense","SNP"],["PIK3CA","Inframe","INS"]],"hovertemplate":"Hugo_Symbol=%{customdata[0]}\u003cbr\u003eStart_Position=%{x}\u003cbr\u003eChromosome=%{y}\u003cbr\u003eVariant_Classification=%{customdata[1]}\u003cbr\u003eVariant_Type=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PIK3CA","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"PIK3CA","orientation":"h","showlegend":true,"x":[178952000,178952500],"xaxis":"x","y":["3","3"],"yaxis":"y","type":"scatter"},{"customdata":[["KRAS","Nonsense","SNP"],["KRAS","Missense","SNP"]],"hovertemplate":"Hugo_Symbol=%{customdata[0]}\u003cbr\u003eStart_Position=%{x}\u003cbr\u003eChromosome=%{y}\u003cbr\u003eVariant_Classification=%{customdata[1]}\u003cbr\u003eVariant_Type=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"KRAS","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"KRAS","orientation":"h","showlegend":true,"x":[25398200,25398300],"xaxis":"x","y":["12","12"],"yaxis":"y","type":"scatter"},{"customdata":[["APC","Missense","SNP"]],"hovertemplate":"Hugo_Symbol=%{customdata[0]}\u003cbr\u003eStart_Position=%{x}\u003cbr\u003eChromosome=%{y}\u003cbr\u003eVariant_Classification=%{customdata[1]}\u003cbr\u003eVariant_Type=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"APC","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"APC","orientation":"h","showlegend":true,"x":[112175000],"xaxis":"x","y":["5"],"yaxis":"y","type":"scatter"},{"customdata":[["BRAF","Missense","SNP"]],"hovertemplate":"Hugo_Symbol=%{customdata[0]}\u003cbr\u003eStart_Position=%{x}\u003cbr\u003eChromosome=%{y}\u003cbr\u003eVariant_Classification=%{customdata[1]}\u003cbr\u003eVariant_Type=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BRAF","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"BRAF","orientation":"h","showlegend":true,"x":[140753336],"xaxis":"x","y":["7"],"yaxis":"y","type":"scatter"},{"customdata":[["PTEN","Nonsense","SNP"]],"hovertemplate":"Hugo_Symbol=%{customdata[0]}\u003cbr\u003eStart_Position=%{x}\u003cbr\u003eChromosome=%{y}\u003cbr\u003eVariant_Classification=%{customdata[1]}\u003cbr\u003eVariant_Type=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"PTEN","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"PTEN","orientation":"h","showlegend":true,"x":[89720000],"xaxis":"x","y":["10"],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.666666666 ...

# %% [markdown]
# ## 6. Interactive Filter (Dropdown: Filter by Gene)

# %%
genes = df["Hugo_Symbol"].unique()

fig = go.Figure()

for g in genes:
    sub = df[df["Hugo_Symbol"]==g]
    fig.add_trace(go.Scatter(
        x=sub["Start_Position"],
        y=sub["Chromosome"],
        mode="markers",
        name=g,
        visible=(g==genes[0])
    ))

fig.update_layout(
    title="Interactive: Filter Mutations by Gene",
    updatemenus=[{
        "buttons":[
            {
                "label":g,
                "method":"update",
                "args":[{"visible":[x==i for i in range(len(genes))]}]
            } for x,g in enumerate(genes)
        ]
    }]
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="907a792b-7233-41eb-9459-efdf7a83d087" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("907a792b-7233-41eb-9459-efdf7a83d087")) {                    Plotly.newPlot(                        "907a792b-7233-41eb-9459-efdf7a83d087",                        [{"mode":"markers","name":"TP53","visible":true,"x":[7574000,7573920,7574100],"y":["17","17","17"],"type":"scatter"},{"mode":"markers","name":"PIK3CA","visible":false,"x":[178952000,178952500],"y":["3","3"],"type":"scatter"},{"mode":"markers","name":"KRAS","visible":false,"x":[25398200,25398300],"y":["12","12"],"type":"scatter"},{"mode":"markers","name":"APC","visible":false,"x":[112175000],"y":["5"],"type":"scatter"},{"mode":"markers","name":"BRAF","visible":false,"x":[140753336],"y":["7"],"type":"scatter"},{"mode":"markers","name":"PTEN","visible":false,"x":[89720000],"y":["10"],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"err ...
